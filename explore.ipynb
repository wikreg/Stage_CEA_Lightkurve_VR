# %%
from utils.plotly import explore
# Out:
# c:\Users\simon\OneDrive\Bureau\Stage_CEA_Lightkurve\stageL1lk\Lib\site-packages\lightkurve\prf\__init__.py:7: UserWarning: Warning: the tpfmodel submodule is not available without oktopus installed, which requires a current version of autograd. See #1452 for details.
#   warnings.warn(

# %%
explore(target="KIC 10264202", normalized=True, bins=100)
# Out:
# Searching for lightcurves of 'KIC 10264202'...
#
# Available lightcurves:
#     Choice            mission  year  author  exptime    target_name  distance
# 0        0  Kepler Quarter 01  2009  Kepler   1800.0  kplr010264202       0.0
# 1        1  Kepler Quarter 02  2009  Kepler   1800.0  kplr010264202       0.0
# 2        2  Kepler Quarter 03  2009  Kepler   1800.0  kplr010264202       0.0
# 3        3  Kepler Quarter 04  2010  Kepler   1800.0  kplr010264202       0.0
# 4        4  Kepler Quarter 05  2010  Kepler   1800.0  kplr010264202       0.0
# 5        5  Kepler Quarter 06  2010  Kepler   1800.0  kplr010264202       0.0
# 6        6  Kepler Quarter 07  2010  Kepler   1800.0  kplr010264202       0.0
# 7        7  Kepler Quarter 10  2011  Kepler   1800.0  kplr010264202       0.0
# 8        8  Kepler Quarter 09  2011  Kepler   1800.0  kplr010264202       0.0
# 9        9  Kepler Quarter 08  2011  Kepler   1800.0  kplr010264202       0.0
# ...
